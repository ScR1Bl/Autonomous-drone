# %% [markdown]
# # **Propozycja symulatora:**

# %% [markdown]
# ## **ROS2 Jazzy** - framework robotyczny
#
# ## **Gazebo Harmonic** - symulator fizyki
#
# ## **PX4-Autopilot** - oprogramowanie do flight controller
#
# ## **Micro XRCE-DDS** Agent
#
# ## **px4_msgs** - definicje typów wiadomości PX4 dla ROS2

# %% [markdown]
# **Procedura uruchomienia (3 terminale, w tej kolejności)**
#
#
# **Terminal 1** — Agent (zawsze pierwszy):
#
# MicroXRCEAgent udp4 -p 8888
#
# **Terminal 2** — PX4 SITL + Gazebo:
#
# source ~/px4-venv/bin/activate
#
# cd ~/PX4-Autopilot
#
# make px4_sitl gz_x500
#
# **Terminal 3** — ROS2:
#
# source /opt/ros/jazzy/setup.bash
#
# source ~/Desktop/PROJEKTY/SIiUM/Projekt-zespolowy/Dron/ros2_ws/install/setup.bash
#
# ros2 topic echo /fmu/out/vehicle_local_position_v1 --once

# %% [markdown]
# + test
